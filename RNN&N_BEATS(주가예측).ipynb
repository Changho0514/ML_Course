# %% [markdown]
# <a href="https://colab.research.google.com/github/Changho0514/web1/blob/main/RNN%26N_BEATS(%EC%A3%BC%EA%B0%80%EC%98%88%EC%B8%A1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 주식 시장 예측해보기
#
# resource: https://www.kaggle.com/faressayah/stock-market-analysis-prediction-using-lstm

# %% [markdown]
# #### 이번 실습에서는 주가 데이터를 예측하는 일을 해볼 것 입니다.
# #### RNN, LSTM, GRU, N-BEATS 모델을 통해 미래의 주가를 예측해봅시다.

# %% [markdown]
# # 1. Pandas 를 이용한 데이터 전처리 및 matplotlib, seaborn 을 이용한 데이터 시각화

# %%
from datetime import datetime
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# !pip install yfinance
import yfinance as yf
from datetime import datetime

# Apple, Google, Microsoft, Amazon 데이터를 수집해봅시다
tech_list = ['AAPL', 'GOOG', 'MSFT', 'AMZN']

end = datetime.now()
start = datetime(end.year - 10, end.month, end.day) # 오늘부터 이전 10년간의 데이터를 모아봅시다.

for stock in tech_list:
    globals()[stock] = yf.download(stock, start, end) # yfinance 라이브러리는 주식 데이터를 자동으로 다운로드 받게 해줍니다.
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.68-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.19.5)
# Collecting requests>=2.26
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 957 kB/s
# Collecting lxml>=4.5.1
#   Downloading lxml-4.7.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 8.2 MB/s
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Installing collected packages: requests, lxml, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed lxml-4.7.1 requests-2.27.1 yfinance-0.1.68
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Let's go ahead and play aorund with the AAPL DataFrame to get a feel for the data

# %%
company_list = [AAPL, GOOG, MSFT, AMZN]
company_name = ["APPLE", "GOOGLE", "MICROSOFT", "AMAZON"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
    
df = pd.concat(company_list, axis=0)

# %% [markdown]
# 데이터는 6가지의 feature로 구성되어 있습니다.
# 1. Open(시작가)
# 2. High(최고가)
# 3. Low(최저가)
# 4. Close(종가)
# 5. Adj Close(조정된 종가)
# 6. Volume(거래량)

# %%
df
# Out:
#                    Open         High  ...     Volume  company_name
# Date                                  ...
# 2012-01-12    15.081429    15.103571  ...  212587200         APPLE
# 2012-01-13    14.989286    15.016071  ...  226021600         APPLE
# 2012-01-17    15.150000    15.213929  ...  242897200         APPLE
# 2012-01-18    15.248571    15.338214  ...  276791200         APPLE
# 2012-01-19    15.362500    15.406071  ...  261738400         APPLE
# ...                 ...          ...  ...        ...           ...
# 2022-01-05  3337.659912  3342.530029  ...    3215100        AMAZON
# 2022-01-06  3269.010010  3296.000000  ...    2597900        AMAZON
# 2022-01-07  3276.780029  3304.870117  ...    2329300        AMAZON
# 2022-01-10  3211.709961  3233.229980  ...    4389900        AMAZON
# 2022-01-11  3230.000000  3327.000000  ...    3131500        AMAZON
#
# [10068 rows x 7 columns]

# %%
# Summary Stats
AAPL.describe()
# Out:
#               Open         High  ...    Adj Close        Volume
# count  2517.000000  2517.000000  ...  2517.000000  2.517000e+03
# mean     49.462477    49.981625  ...    47.737024  2.145457e+08
# std      39.220763    39.693572  ...    39.903133  1.759101e+08
# min      13.856071    14.271429  ...    12.134603  4.100000e+07
# 25%      23.732500    23.934999  ...    21.353045  1.027696e+08
# 50%      32.517502    32.735001  ...    29.691391  1.506940e+08
# 75%      54.447498    55.112499  ...    52.694378  2.644760e+08
# max     182.630005   182.940002  ...   182.009995  1.506120e+09
#
# [8 rows x 6 columns]

# %%
# General info
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2517 entries, 2012-01-12 to 2022-01-11
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          2517 non-null   float64
#  1   High          2517 non-null   float64
#  2   Low           2517 non-null   float64
#  3   Close         2517 non-null   float64
#  4   Adj Close     2517 non-null   float64
#  5   Volume        2517 non-null   int64
#  6   company_name  2517 non-null   object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 157.3+ KB

# %%
# 과거의 종가 데이터를 한번 확인해봅시다.


plt.figure(figsize=(15, 6))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"Closing Price of {tech_list[i - 1]}")
    
plt.tight_layout()

# %%
# 과거의 거래량을 확인해봅시다.
plt.figure(figsize=(15, 7))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Volume'].plot()
    plt.ylabel('Volume')
    plt.xlabel(None)
    plt.title(f"Sales Volume for {tech_list[i - 1]}")
    
plt.tight_layout()

# %%
df.groupby("company_name").hist(figsize=(12, 12))
# Out:
# company_name
# AMAZON       [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# APPLE        [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# GOOGLE       [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# MICROSOFT    [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# dtype: object

# %% [markdown]
# # 2. Moving average를 통해 데이터의 변화 양상을 확인해봅시다.

# %%
ma_day = [10, 20, 50, 200] # 10일치, 20일치, 50일치의 moving average를 통해 변화양상을 확인해봅시다.

# sliding window가 10, 20, 50 인 것으로 생각
for ma in ma_day:
    for company in company_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Adj Close'].rolling(ma).mean()  # .rolling(ma)써서 기간 평균값 새로 추가하기 - MA for [10/20/50] 추가됐음

# %%
print(GOOG.columns)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'company_name',
#        'MA for 10 days', 'MA for 20 days', 'MA for 50 days',
#        'MA for 200 days'],
#       dtype='object')

# %% [markdown]
# - moving average에 사용되는 window의 크기가 클수록 더 긴 기간의 trend를 확인할 수 있고, window의 크기가 작을수록 짧은 구간의 trend 변화를 확인할 수 있습니다.

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(8)
fig.set_figwidth(15)

plot_columns = ['Adj Close', 'MA for 10 days', 'MA for 200 days']  # 'MA for 20 days', 'MA for 50 days']

AAPL[plot_columns].plot(ax=axes[0,0])   #.iloc[-500:].plot(ax=axes[0,0])
axes[0,0].set_title('APPLE')

GOOG[plot_columns].plot(ax=axes[0,1])
axes[0,1].set_title('GOOGLE')

MSFT[plot_columns].plot(ax=axes[1,0])
axes[1,0].set_title('MICROSOFT')

AMZN[plot_columns].plot(ax=axes[1,1])
axes[1,1].set_title('AMAZON')

fig.tight_layout()

# %% [markdown]
# # 3. 수익률을 분석해봅시다.
# - Pandas dataframe 은 pct_change 라는 수익률 분석 함수를 제공합니다. 이 함수는 아래의 값을 계산합니다.
#     - (현재 값 - 직전 값)/직전 값
#     - 종가에 적용하면 전날 종가대비 당일의 종가가 얼마나 상승했는지를 비율로 나타내게 됩니다.

# %%
# We'll use pct_change to find the percent change for each day
for company in company_list:
    company['Daily Return'] = company['Adj Close'].pct_change()

# Then we'll plot the daily return percentage
fig, axes = plt.subplots(nrows=2, ncols=2) # 2 * 2 subplot
fig.set_figheight(8)
fig.set_figwidth(15)

AAPL['Daily Return'][-50:].plot(ax=axes[0,0], legend=True, linestyle='--', marker='o') #이렇게 하면 최근 50일간의 데이터까지만 구해올 수 있음
axes[0,0].set_title('APPLE')

GOOG['Daily Return'].plot(ax=axes[0,1], legend=True, linestyle='--', marker='o')
axes[0,1].set_title('GOOGLE')

MSFT['Daily Return'].plot(ax=axes[1,0], legend=True, linestyle='--', marker='o')
axes[1,0].set_title('MICROSOFT')

AMZN['Daily Return'].plot(ax=axes[1,1], legend=True, linestyle='--', marker='o')
axes[1,1].set_title('AMAZON')

fig.tight_layout()

# %% [markdown]
# - Histogram 을 이용해서도 분석해봅시다. (Seaborn 라이브러리 이용)

# %%
plt.figure(figsize=(12, 7))

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    sns.distplot(company['Daily Return'].dropna(), bins=100, color='purple') # nan value는 seaborn 에서 읽을 수 없으므로 dropna 를 통해 처리하였습니다.
    plt.ylabel('Daily Return')
    plt.title(f'{company_name[i - 1]}')
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# pandas dataframe 에서 제공하는 histogram 함수를 사용해도 됩니다.
AAPL['Daily Return'].hist()

# %% [markdown]
# # 4. 서로 다른 주식의 종가들 간의 관계성을 분석해봅시다.

# %% [markdown]
# Now that we have all the closing prices, let's go ahead and get the daily return for all the stocks, like we did for the Apple stock.

# %%
closing_df = pd.DataFrame([AAPL['Adj Close'], GOOG['Adj Close'], MSFT['Adj Close'], AMZN['Adj Close']]).T
closing_df.columns = ['AAPL','GOOG','MSFT','AMZN']

# %%
# Make a new tech returns DataFrame
tech_rets = closing_df.pct_change()
tech_rets.head()   # 2012-01-12가 NaN => 어떠한 이유때문인지 몰라도 NaN값 처리해줘야지
# Out:
#                 AAPL      GOOG      MSFT      AMZN
# Date
# 2012-01-12       NaN       NaN       NaN       NaN
# 2012-01-13 -0.003750 -0.007385  0.008929  0.014153
# 2012-01-17  0.011648  0.005744  0.000354  0.018159
# 2012-01-18  0.010384  0.006889 -0.001061  0.042827
# 2012-01-19 -0.003169  0.010523 -0.003897  0.026446

# %% [markdown]
# - seaborn 라이브러리의 jointplot을 통해 관계성을 분석해봅시다.

# %%
# 자기 자신과의 비교를 먼저 진행해봅시다. 자기 자신과 비교하면 correlation이 아주 강하게 나타나는 것을 볼 수 있습니다. (correlation = 1.0, 정비례)
sns.jointplot('GOOG', 'GOOG', tech_rets, kind='scatter', color='seagreen')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Google 과 Microsoft를 비교해봅시다.
sns.jointplot('GOOG', 'MSFT', tech_rets, kind='scatter')
sns.jointplot('GOOG', 'MSFT', tech_rets, kind='scatter')
sns.jointplot('GOOG', 'MSFT', tech_rets, kind='scatter')
sns.jointplot('GOOG', 'MSFT', tech_rets, kind='scatter')

"""
결과를 통해 아래의 질문에 답을 해보세요.
1. correlation이 높은가요? 아니면 낮은가요?
2. 그렇다면 Google 주식을 feature로 사용하면 Microsoft 주식을 예측할 때 도움이 될까요?
"""
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# '\n결과를 통해 아래의 질문에 답을 해보세요.\n1. correlation이 높은가요? 아니면 낮은가요?\n2. 그렇다면 Google 주식을 feature로 사용하면 Microsoft 주식을 예측할 때 도움이 될까요?\n'

# %% [markdown]
# - Pandas와 seaborn을 혼합하면 이러한 분석을 모든 pair에 대해 아주 쉽게 적용할 수 있습니다.

# %%
# We can simply call pairplot on our DataFrame for an automatic visual analysis 
# of all the comparisons

sns.pairplot(tech_rets, kind='reg')

# %% [markdown]
# - Seaborn 의 pairplot은 pairgrid 함수를 통해 좀 더 다양한 버전으로 적용될 수 있습니다. 이를 통해 다양한 방식으로 데이터를 분석하는 것이 가능합니다.
#     - 여기서는 이를 통해 분석을 진행하기보다는, 사용하는 방법에 대해서만 확인하고 넘어가도록 하겠습니다.
#     - 이 예제에서는 위쪽 삼각형에서는 scatter plot, 아래쪽 삼각형에서는 kernel density estimation plot, 대각에는 histogram을 그려보겠습니다.

# %%
# 우선, 수익률을 통해 분석해봅시다.
return_fig = sns.PairGrid(tech_rets.dropna())

return_fig.map_upper(plt.scatter, color='purple')
return_fig.map_lower(sns.kdeplot, cmap='cool_d') # kde 에서 회색 선은 등고선을 의미합니다
return_fig.map_diag(plt.hist, bins=30)

# %%
# 종가 데이터를 통해 분석해봅시다.
returns_fig = sns.PairGrid(closing_df)

returns_fig.map_upper(plt.scatter,color='purple')
returns_fig.map_lower(sns.kdeplot,cmap='cool_d')
returns_fig.map_diag(plt.hist,bins=30)

# %% [markdown]
# - pandas 의 corr 함수를 통해 pearson correlation을 간단히 계산할 수도 있습니다.

# %%
sns.heatmap(tech_rets.corr(), annot=True, cmap='viridis')

# %%
sns.heatmap(closing_df.corr(), annot=True, cmap='viridis')

# %% [markdown]
# # 5. Apple, Google, Microsoft, Amazon의 주식 종가를 예측해봅시다.

# %%
df = closing_df

# %%
df.columns
# Out:
# Index(['AAPL', 'GOOG', 'MSFT', 'AMZN'], dtype='object')

# %%
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df['AAPL'], label='Apple')
plt.plot(df['GOOG'], label='Google')
plt.plot(df['MSFT'], label='Microsoft')
plt.plot(df['AMZN'], label='Amazon')
plt.legend(loc='upper left')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %% [markdown]
# # 5-1. 데이터 전처리

# %%
# data split 
train_data_length = int(len(df) * 0.8)
val_data_length = int(len(df) * 0.1)

train_df = df.iloc[:train_data_length]   #8년은 train
val_df = df.iloc[train_data_length:train_data_length+val_data_length] #8년 이후 1년은 validation
test_df = df.iloc[train_data_length+val_data_length:]   #나머지 1년은 test   #shuffle안하고 앞에서 잘라야해

# %%
train_df.shape, val_df.shape, test_df.shape
# Out:
# ((2013, 4), (251, 4), (253, 4))

# %% [markdown]
# # 5-2. Dataset class 만들기, Dataloader 만들기

# %%
class StandardScaler():
    def __init__(self):
        self.mean = None
        self.stdev = None
        
    def fit(self, x, dim=None):
        if not torch.is_tensor(x): # numpy array -> torch tensor 
            x = torch.tensor(x)# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        
        if dim is not None:
            self.mean = x.mean(dim) # x.shape = (batch=8, )
            self.stdev = x.std(dim)
        else:
            self.mean = x.mean()
            self.stdev = x.std()
        
    def scale(self, x):# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        if not torch.is_tensor(x): # numpy array -> torch tensor 
            x = torch.tensor(x)
        return (x - self.mean.to(x.device)) / self.stdev.to(x.device)  # 둘다 gpu에 있든, cpu에 있든 똑같은 곳에 있어야 연산이 된다. 
    
    def unscale(self, x):
        if not torch.is_tensor(x): # numpy array -> torch tensor 
            x = torch.tensor(x)
        return x * self.stdev.to(x.device) + self.mean.to(x.device) # 역 연산으로 원래 scale로 돌아가게 한다.
# We can simply call pairplot on our DataFrame for an automatic visual analysis 

class TimeseriesDataset(torch.utils.data.Dataset):   
    def __init__(self, data, backcast_length, forecast_length, scaler=None):
        self.data_columns = data.columns
        self.data = data.values
        self.backcast_length = backcast_length
        self.forecast_length = forecast_length
        
        if scaler is None:
            # train
            self.scaler = StandardScaler()
            self.scaler.fit(self.data, dim=0)
        else:
            self.scaler = scaler
        self.data = self.scaler.scale(self.data)
        

    def __len__(self):
        return len(self.data) - self.backcast_length - self.forecast_length + 1     #sliding window때문에. 그 size를 유지해 주는 것

    def __getitem__(self, idx):
        x_end = idx + self.backcast_length
        y_end = x_end + self.forecast_length

        x = self.data[idx:x_end]
        y = self.data[x_end:y_end]
        
        x = x.float()
        y = y.float()
        
        return x, y 
    
    def unscale(self, x):
        return self.scaler.unscale(x)

# %%
batch_size = 128
num_workers = 2
pin_memory = True

backcast_length = 30
forecast_length = 30

# %%
train_dataset = TimeseriesDataset(train_df, backcast_length, forecast_length, scaler=None)
val_dataset = TimeseriesDataset(val_df, backcast_length, forecast_length, scaler=train_dataset.scaler)
test_dataset = TimeseriesDataset(test_df, backcast_length, forecast_length, scaler=train_dataset.scaler)

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, 
                                               num_workers=num_workers, pin_memory=pin_memory)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False, 
                                               num_workers=num_workers, pin_memory=pin_memory)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, 
                                               num_workers=num_workers, pin_memory=pin_memory)

# %% [markdown]
# # 5-3. 모델 정의하기

# %%
class RNNmodel(nn.Module):
    def __init__(self, feature_dim, hidden_dim, LSTM=False, GRU=False, num_layers=4, bidirectional=False, dropout=0.3, batch_first=True, backcast_length=30, forecast_length=30):
        super(RNNmodel, self).__init__()
        # hidden_dim : 키우면 모델도 커짐. LSTM, GRU둘중 하나만 True여야 함. bidirectional은 앞으로도 영향을 줄 수 있기 때문에 만들어준 값. generalize잘하게끔 dropout(무작위로 없애기) time_series에서는 batch_first는 항상!
        self.LSTM = LSTM # LSTM인지 아닌지 여부를 저장해둡니다.
        self.n_direction = 2 if bidirectional else 1
        self.backcast_length = backcast_length 
        self.forecast_length = forecast_length
        self.num_layers = num_layers
        self.hidden_dim = hidden_dim
        
        
        if LSTM:
            rnn = nn.LSTM
        elif GRU: 
            rnn = nn.GRU
        else:
            rnn = nn.RNN
            
            
        self.rnn = rnn(input_size = feature_dim, 
                       hidden_size = hidden_dim, 
                       num_layers = num_layers,
                       bias = True,
                       batch_first = batch_first,
                       dropout = dropout,
                       bidirectional = bidirectional)# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        self.out = nn.Linear(hidden_dim * self.n_direction, feature_dim)  # bidrection이면 2배가 됨. 
        
    def forward(self, x):
        # x: (batch, sequence length, feature_dim)
        
        
        # many to many 구조를 구현해봅시다.
        
        if self.LSTM:
            h0 = (torch.zeros(self.num_layers * self.n_direction, x.shape[0], self.hidden_dim, device=x.device),
                  torch.zeros(self.num_layers * self.n_direction, x.shape[0], self.hidden_dim, device=x.device))
        else:
            h0 = torch.zeros(self.num_layers * self.n_direction, x.shape[0], self.hidden_dim, device=x.device)
        
        x, h = self.rnn(x, h0)
        outs = []
        for i in range(self.forecast_length):
            x = self.out(x[:,-1:,:])
            outs.append(x.squeeze(1))
            
            if i == self.forecast_length-1:
                break
                
            x, h = self.rnn(x, h) # x, h 를 받아서 다시 x, h를 리턴한다. rnn에서 나온 vector가 hidden을 거쳐서 output 생성, 또 다른 input으로 바꾼다. outs=[]에 모아놓기.
            
        outs = torch.stack(outs, dim=1) # batch, forecatst_length, feature_dim
        return outs

# %%
feature_dim=4
hidden_dim=64

model = RNNmodel(feature_dim, hidden_dim, LSTM=False, GRU=True)

# %% [markdown]
# # 5-4. 학습 방식 정의하기

# %%
learning_rate = 1e-4

criterion = nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# # 5-5. 학습 진행하기

# %%
num_epoch = 100



import time
train_losses = []
val_losses = []
best_epoch = 0
start_time = time.time()
best_model_state_dict = None
best_val_loss = 10000   # 매우 큰 수로 놓고, loss는 이것보다 작아질 것이기 때문에.

for epoch in range(num_epoch):
    train_loss_mean = 0
    val_loss_mean = 0
    
    # train
    model.train()
    for i, (inputs, labels) in enumerate(train_dataloader):
#         inputs = inputs.cuda()
#         labels = labels.cuda()
        
        forecast = model(inputs)
    
        forecast = model(inputs)
        loss = criterion(forecast.sum(0), labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_loss_mean += loss.item()
        
        if i % 100 == 0:
            print('epoch [{}/{}] iter [{:03d}/{:03d}] loss [{:.4f}] elapsed time [{:.2f}min]'.format(epoch, num_epoch, i, len(train_dataloader), loss.item(), (time.time()-start_time)/60))
    
    train_loss_mean = train_loss_mean/len(train_dataloader)
    
    train_losses.append(train_loss_mean)
    
    # validation
    model.eval()
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(val_dataloader):
#             inputs = inputs.cuda()
#             labels = labels.cuda()

            forecast = model(inputs)
            loss = criterion(forecast.sum(0), labels)
            val_loss_mean += loss.item()

        val_loss_mean = val_loss_mean/len(val_dataloader)

        print('epoch [{}/{}] train loss [{:.4f}] validation loss [{:.4f}] elapsed time [{:.2f} min]\n'.format(epoch, num_epoch, train_loss_mean, val_loss_mean, (time.time()-start_time)/60))

        if val_loss_mean < best_val_loss:
            best_epoch = epoch
            best_val_loss = val_loss_mean
            best_model_state_dict = model.state_dict()
    val_losses.append(val_loss_mean)# We can simply call pairplot on our DataFrame for an automatic visual analysis
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:96: UserWarning: Using a target size (torch.Size([128, 30, 4])) that is different to the input size (torch.Size([30, 4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.l1_loss(input, target, reduction=self.reduction)
# epoch [0/100] iter [000/016] loss [9.5993] elapsed time [0.15min]
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:96: UserWarning: Using a target size (torch.Size([34, 30, 4])) that is different to the input size (torch.Size([30, 4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.l1_loss(input, target, reduction=self.reduction)
# epoch [0/100] train loss [5.7153] validation loss [5.3207] elapsed time [0.23 min]
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:96: UserWarning: Using a target size (torch.Size([64, 30, 4])) that is different to the input size (torch.Size([30, 4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.l1_loss(input, target, reduction=self.reduction)
# epoch [1/100] iter [000/016] loss [3.2919] elapsed time [0.24min]
# epoch [1/100] train loss [1.8497] validation loss [3.6898] elapsed time [0.33 min]
#
# epoch [2/100] iter [000/016] loss [1.1168] elapsed time [0.34min]
# epoch [2/100] train loss [1.0314] validation loss [4.2812] elapsed time [0.43 min]
#
# epoch [3/100] iter [000/016] loss [0.8590] elapsed time [0.44min]
# epoch [3/100] train loss [0.8600] validation loss [4.2187] elapsed time [0.53 min]
#
# epoch [4/100] iter [000/016] loss [0.7972] elapsed time [0.54min]
# epoch [4/100] train loss [0.8234] validation loss [4.1598] elapsed time [0.63 min]
#
# epoch [5/100] iter [000/016] loss [0.7797] elapsed time [0.64min]
# epoch [5/100] train loss [0.8122] validation loss [4.2121] elapsed time [0.72 min]
#
# epoch [6/100] iter [000/016] loss [0.8008] elapsed time [0.73min]
# epoch [6/100] train loss [0.8089] validation loss [4.2382] elapsed time [0.83 min]
#
# epoch [7/100] iter [000/016] loss [0.7970] elapsed time [0.84min]
# epoch [7/100] train loss [0.8115] validation loss [4.1640] elapsed time [0.93 min]
#
# epoch [8/100] iter [000/016] loss [0.7152] elapsed time [0.94min]
# epoch [8/100] train loss [0.8128] validation loss [4.0794] elapsed time [1.03 min]
#
# epoch [9/100] iter [000/016] loss [0.7601] elapsed time [1.04min]
# epoch [9/100] train loss [0.8101] validation loss [4.0099] elapsed time [1.13 min]
#
# epoch [10/100] iter [000/016] loss [0.8491] elapsed time [1.14min]
# epoch [10/100] train loss [0.8132] validation loss [4.0721] elapsed time [1.23 min]
#
# epoch [11/100] iter [000/016] loss [0.7550] elapsed time [1.24min]
# epoch [11/100] train loss [0.8023] validation loss [4.0895] elapsed time [1.33 min]
#
# epoch [12/100] iter [000/016] loss [0.8281] elapsed time [1.34min]
# epoch [12/100] train loss [0.8099] validation loss [4.0099] elapsed time [1.43 min]
#
# epoch [13/100] iter [000/016] loss [0.8662] elapsed time [1.44min]
# epoch [13/100] train loss [0.8026] validation loss [4.1047] elapsed time [1.53 min]
#
# epoch [14/100] iter [000/016] loss [0.8018] elapsed time [1.54min]
# epoch [14/100] train loss [0.8085] validation loss [4.0812] elapsed time [1.63 min]
#
# epoch [15/100] iter [000/016] loss [0.7155] elapsed time [1.64min]
# epoch [15/100] train loss [0.8083] validation loss [4.0544] elapsed time [1.73 min]
#
# epoch [16/100] train loss [0.8009] validation loss [3.9069] elapsed time [1.83 min]
#
# epoch [17/100] iter [000/016] loss [0.8712] elapsed time [1.84min]
# epoch [17/100] train loss [0.7999] validation loss [3.9429] elapsed time [1.92 min]
#
# epoch [18/100] iter [000/016] loss [0.9060] elapsed time [1.94min]
# epoch [18/100] train loss [0.8012] validation loss [3.9687] elapsed time [2.03 min]
#
# epoch [19/100] iter [000/016] loss [0.8017] elapsed time [2.04min]
# epoch [19/100] train loss [0.8090] validation loss [4.0796] elapsed time [2.12 min]
#
# epoch [20/100] iter [000/016] loss [0.7084] elapsed time [2.13min]
# epoch [20/100] train loss [0.8120] validation loss [3.8122] elapsed time [2.22 min]
#
# epoch [21/100] iter [000/016] loss [0.8085] elapsed time [2.23min]
# epoch [21/100] train loss [0.8103] validation loss [3.8279] elapsed time [2.32 min]
#
# epoch [22/100] iter [000/016] loss [0.7943] elapsed time [2.33min]
# epoch [22/100] train loss [0.8039] validation loss [4.0108] elapsed time [2.42 min]
#
# epoch [23/100] iter [000/016] loss [0.8045] elapsed time [2.43min]
# epoch [23/100] train loss [0.8183] validation loss [3.8902] elapsed time [2.52 min]
#
# epoch [24/100] iter [000/016] loss [0.7241] elapsed time [2.54min]
# epoch [24/100] train loss [0.8063] validation loss [3.7958] elapsed time [2.63 min]
#
# epoch [25/100] iter [000/016] loss [0.7393] elapsed time [2.64min]
# epoch [25/100] train loss [0.8036] validation loss [3.7621] elapsed time [2.72 min]
#
# epoch [26/100] iter [000/016] loss [0.8769] elapsed time [2.73min]
# epoch [26/100] train loss [0.8123] validation loss [3.7932] elapsed time [2.82 min]
#
# epoch [27/100] iter [000/016] loss [0.7555] elapsed time [2.83min]
# epoch [27/100] train loss [0.8086] validation loss [3.8808] elapsed time [2.92 min]
#
# epoch [28/100] iter [000/016] loss [0.8825] elapsed time [2.93min]
# epoch [28/100] train loss [0.8042] validation loss [3.6741] elapsed time [3.02 min]
#
# epoch [29/100] iter [000/016] loss [0.8498] elapsed time [3.03min]
# epoch [29/100] train loss [0.8066] validation loss [3.8577] elapsed time [3.12 min]
#
# epoch [30/100] iter [000/016] loss [0.8960] elapsed time [3.13min]
# epoch [30/100] train loss [0.7957] validation loss [3.9174] elapsed time [3.22 min]
#
# epoch [31/100] iter [000/016] loss [0.8414] elapsed time [3.23min]
# epoch [31/100] train loss [0.8015] validation loss [3.7693] elapsed time [3.32 min]
#
# epoch [32/100] iter [000/016] loss [0.8882] elapsed time [3.33min]
# epoch [32/100] train loss [0.8060] validation loss [3.7297] elapsed time [3.42 min]
#
# epoch [33/100] iter [000/016] loss [0.8337] elapsed time [3.43min]
# epoch [33/100] train loss [0.8100] validation loss [3.9318] elapsed time [3.52 min]
#
# epoch [34/100] iter [000/016] loss [0.8190] elapsed time [3.53min]
# epoch [34/100] train loss [0.8063] validation loss [3.8274] elapsed time [3.62 min]
#
# epoch [35/100] iter [000/016] loss [0.7546] elapsed time [3.63min]
# epoch [35/100] train loss [0.7998] validation loss [3.9398] elapsed time [3.72 min]
#
# epoch [36/100] iter [000/016] loss [0.8389] elapsed time [3.73min]
# epoch [36/100] train loss [0.8117] validation loss [3.7519] elapsed time [3.82 min]
#
# epoch [37/100] iter [000/016] loss [0.7162] elapsed time [3.83min]
# epoch [37/100] train loss [0.8091] validation loss [3.5648] elapsed time [3.92 min]
#
# epoch [38/100] iter [000/016] loss [0.8787] elapsed time [3.93min]
# epoch [38/100] train loss [0.8240] validation loss [3.9317] elapsed time [4.02 min]
#
# epoch [39/100] iter [000/016] loss [0.7817] elapsed time [4.03min]
# epoch [39/100] train loss [0.8194] validation loss [3.8119] elapsed time [4.12 min]
#
# epoch [40/100] iter [000/016] loss [0.8297] elapsed time [4.13min]
# epoch [40/100] train loss [0.8150] validation loss [3.6649] elapsed time [4.22 min]
#
# epoch [41/100] iter [000/016] loss [0.8365] elapsed time [4.23min]
# epoch [41/100] train loss [0.8303] validation loss [3.9458] elapsed time [4.32 min]
#
# epoch [42/100] iter [000/016] loss [0.8040] elapsed time [4.33min]
# epoch [42/100] train loss [0.8139] validation loss [3.8227] elapsed time [4.42 min]
#
# epoch [43/100] iter [000/016] loss [0.7525] elapsed time [4.43min]
# epoch [43/100] train loss [0.8046] validation loss [3.7550] elapsed time [4.52 min]
#
# epoch [44/100] iter [000/016] loss [0.8496] elapsed time [4.53min]
# epoch [44/100] train loss [0.8135] validation loss [3.9075] elapsed time [4.62 min]
#
# epoch [45/100] iter [000/016] loss [0.8131] elapsed time [4.63min]
# epoch [45/100] train loss [0.8120] validation loss [3.6872] elapsed time [4.71 min]
#
# epoch [46/100] iter [000/016] loss [0.8092] elapsed time [4.72min]
# epoch [46/100] train loss [0.8092] validation loss [3.7866] elapsed time [4.81 min]
#
# epoch [47/100] iter [000/016] loss [0.7990] elapsed time [4.82min]
# epoch [47/100] train loss [0.8032] validation loss [3.6795] elapsed time [4.91 min]
#
# epoch [48/100] iter [000/016] loss [0.7991] elapsed time [4.92min]
# epoch [48/100] train loss [0.8051] validation loss [3.6002] elapsed time [5.01 min]
#
# epoch [49/100] iter [000/016] loss [0.7741] elapsed time [5.02min]
# epoch [49/100] train loss [0.8071] validation loss [3.7914] elapsed time [5.11 min]
#
# epoch [50/100] iter [000/016] loss [0.8547] elapsed time [5.12min]
# epoch [50/100] train loss [0.8144] validation loss [3.7761] elapsed time [5.21 min]
#
# epoch [51/100] iter [000/016] loss [0.8298] elapsed time [5.22min]
# epoch [51/100] train loss [0.7950] validation loss [3.7894] elapsed time [5.30 min]
#
# epoch [52/100] iter [000/016] loss [0.8678] elapsed time [5.32min]
# epoch [52/100] train loss [0.8106] validation loss [3.8353] elapsed time [5.41 min]
#
# epoch [53/100] iter [000/016] loss [0.7948] elapsed time [5.42min]
# epoch [53/100] train loss [0.8081] validation loss [3.6118] elapsed time [5.51 min]
#
# epoch [54/100] iter [000/016] loss [0.8240] elapsed time [5.52min]
# epoch [54/100] train loss [0.8117] validation loss [3.7499] elapsed time [5.61 min]
#
# epoch [55/100] iter [000/016] loss [0.8022] elapsed time [5.62min]
# epoch [55/100] train loss [0.8123] validation loss [3.6612] elapsed time [5.71 min]
#
# epoch [56/100] iter [000/016] loss [0.8296] elapsed time [5.72min]
# epoch [56/100] train loss [0.8088] validation loss [3.7967] elapsed time [5.81 min]
#
# epoch [57/100] iter [000/016] loss [0.7526] elapsed time [5.82min]
# epoch [57/100] train loss [0.8031] validation loss [3.9100] elapsed time [5.91 min]
#
# epoch [58/100] iter [000/016] loss [0.9092] elapsed time [5.92min]
# epoch [58/100] train loss [0.8117] validation loss [3.6772] elapsed time [6.01 min]
#
# epoch [59/100] iter [000/016] loss [0.7999] elapsed time [6.02min]
# epoch [59/100] train loss [0.8023] validation loss [3.6220] elapsed time [6.11 min]
#
# epoch [60/100] iter [000/016] loss [0.7408] elapsed time [6.12min]
# epoch [60/100] train loss [0.8032] validation loss [3.6572] elapsed time [6.21 min]
#
# epoch [61/100] iter [000/016] loss [0.8550] elapsed time [6.22min]
# epoch [61/100] train loss [0.7993] validation loss [3.7034] elapsed time [6.31 min]
#
# epoch [62/100] iter [000/016] loss [0.8077] elapsed time [6.32min]
# epoch [62/100] train loss [0.8078] validation loss [3.6008] elapsed time [6.41 min]
#
# epoch [63/100] iter [000/016] loss [0.7535] elapsed time [6.42min]
# epoch [63/100] train loss [0.8102] validation loss [3.6811] elapsed time [6.51 min]
#
# epoch [64/100] iter [000/016] loss [0.7398] elapsed time [6.52min]
# epoch [64/100] train loss [0.8064] validation loss [3.7006] elapsed time [6.61 min]
#
# epoch [65/100] iter [000/016] loss [0.7623] elapsed time [6.62min]
# epoch [65/100] train loss [0.8059] validation loss [3.6592] elapsed time [6.71 min]
#
# epoch [66/100] iter [000/016] loss [0.7542] elapsed time [6.72min]
# epoch [66/100] train loss [0.8119] validation loss [3.6286] elapsed time [6.81 min]
#
# epoch [67/100] iter [000/016] loss [0.7922] elapsed time [6.82min]
# epoch [67/100] train loss [0.8053] validation loss [3.6471] elapsed time [6.91 min]
#
# epoch [68/100] iter [000/016] loss [0.8633] elapsed time [6.92min]
# epoch [68/100] train loss [0.8018] validation loss [3.6370] elapsed time [7.01 min]
#
# epoch [69/100] iter [000/016] loss [0.7831] elapsed time [7.02min]
# epoch [69/100] train loss [0.8031] validation loss [3.7866] elapsed time [7.11 min]
#
# epoch [70/100] iter [000/016] loss [0.8091] elapsed time [7.12min]
# epoch [70/100] train loss [0.8080] validation loss [3.6953] elapsed time [7.21 min]
#
# epoch [71/100] iter [000/016] loss [0.7220] elapsed time [7.22min]
# epoch [71/100] train loss [0.8036] validation loss [3.7033] elapsed time [7.31 min]
#
# epoch [72/100] iter [000/016] loss [0.7449] elapsed time [7.32min]
# epoch [72/100] train loss [0.8043] validation loss [3.7575] elapsed time [7.41 min]
#
# epoch [73/100] iter [000/016] loss [0.8092] elapsed time [7.42min]
# epoch [73/100] train loss [0.7985] validation loss [3.7081] elapsed time [7.51 min]
#
# epoch [74/100] iter [000/016] loss [0.6571] elapsed time [7.52min]
# epoch [74/100] train loss [0.8186] validation loss [3.5432] elapsed time [7.61 min]
#
# epoch [75/100] iter [000/016] loss [0.7368] elapsed time [7.62min]
# epoch [75/100] train loss [0.8034] validation loss [3.6309] elapsed time [7.71 min]
#
# epoch [76/100] iter [000/016] loss [0.8199] elapsed time [7.72min]
# epoch [76/100] train loss [0.7972] validation loss [3.7034] elapsed time [7.81 min]
#
# epoch [77/100] iter [000/016] loss [0.8225] elapsed time [7.82min]
# epoch [77/100] train loss [0.8074] validation loss [3.5152] elapsed time [7.91 min]
#
# epoch [78/100] iter [000/016] loss [0.7247] elapsed time [7.92min]
# epoch [78/100] train loss [0.8098] validation loss [3.6371] elapsed time [8.01 min]
#
# epoch [79/100] iter [000/016] loss [0.8505] elapsed time [8.02min]
# epoch [79/100] train loss [0.8088] validation loss [3.5405] elapsed time [8.11 min]
#
# epoch [80/100] iter [000/016] loss [0.7715] elapsed time [8.12min]
# epoch [80/100] train loss [0.7971] validation loss [3.6360] elapsed time [8.21 min]
#
# epoch [81/100] iter [000/016] loss [0.7673] elapsed time [8.22min]
# epoch [81/100] train loss [0.8036] validation loss [3.5576] elapsed time [8.31 min]
#
# epoch [82/100] iter [000/016] loss [0.8860] elapsed time [8.32min]
# epoch [82/100] train loss [0.8029] validation loss [3.7089] elapsed time [8.41 min]
#
# epoch [83/100] iter [000/016] loss [0.7626] elapsed time [8.42min]
# epoch [83/100] train loss [0.8157] validation loss [3.3975] elapsed time [8.51 min]
#
# epoch [84/100] iter [000/016] loss [0.8140] elapsed time [8.52min]
# epoch [84/100] train loss [0.8135] validation loss [3.6092] elapsed time [8.61 min]
#
# epoch [85/100] iter [000/016] loss [0.7998] elapsed time [8.62min]
# epoch [85/100] train loss [0.8046] validation loss [3.5606] elapsed time [8.71 min]
#
# epoch [86/100] iter [000/016] loss [0.8779] elapsed time [8.72min]
# epoch [86/100] train loss [0.8001] validation loss [3.5758] elapsed time [8.81 min]
#
# epoch [87/100] iter [000/016] loss [0.8342] elapsed time [8.82min]
# epoch [87/100] train loss [0.7988] validation loss [3.4972] elapsed time [8.90 min]
#
# epoch [88/100] iter [000/016] loss [0.7216] elapsed time [8.91min]
# epoch [88/100] train loss [0.8034] validation loss [3.6808] elapsed time [9.00 min]
#
# epoch [89/100] iter [000/016] loss [0.8144] elapsed time [9.01min]
# epoch [89/100] train loss [0.8060] validation loss [3.3976] elapsed time [9.10 min]
#
# epoch [90/100] iter [000/016] loss [0.8339] elapsed time [9.11min]
# epoch [90/100] train loss [0.7939] validation loss [3.5133] elapsed time [9.20 min]
#
# epoch [91/100] iter [000/016] loss [0.7185] elapsed time [9.21min]
# epoch [91/100] train loss [0.8064] validation loss [3.5639] elapsed time [9.30 min]
#
# epoch [92/100] iter [000/016] loss [0.8038] elapsed time [9.31min]
# epoch [92/100] train loss [0.8055] validation loss [3.3767] elapsed time [9.40 min]
#
# epoch [93/100] iter [000/016] loss [0.7554] elapsed time [9.41min]
# epoch [93/100] train loss [0.7982] validation loss [3.6286] elapsed time [9.50 min]
#
# epoch [94/100] iter [000/016] loss [0.7772] elapsed time [9.51min]
# epoch [94/100] train loss [0.8110] validation loss [3.6083] elapsed time [9.60 min]
#
# epoch [95/100] iter [000/016] loss [0.7290] elapsed time [9.62min]
# epoch [95/100] train loss [0.8054] validation loss [3.4655] elapsed time [9.70 min]
#
# epoch [96/100] iter [000/016] loss [0.7868] elapsed time [9.71min]
# epoch [96/100] train loss [0.7987] validation loss [3.6848] elapsed time [9.80 min]
#
# epoch [97/100] iter [000/016] loss [0.7654] elapsed time [9.81min]
# epoch [97/100] train loss [0.8013] validation loss [3.5810] elapsed time [9.91 min]
#
# epoch [98/100] iter [000/016] loss [0.7700] elapsed time [9.92min]
# epoch [98/100] train loss [0.8035] validation loss [3.5641] elapsed time [10.01 min]
#
# epoch [99/100] iter [000/016] loss [0.7982] elapsed time [10.02min]
# epoch [99/100] train loss [0.8089] validation loss [3.6544] elapsed time [10.11 min]

# %%
plt.figure(figsize=(10,5))
plt.plot(train_losses, label='train loss')
plt.plot(val_losses, label='validation loss')
plt.axvline(best_epoch, color='red') # early stopping 
plt.legend()
plt.show()

# %% [markdown]
# # validation data 에 대한 실제 값과 예측 값을 확인해봅시다.

# %%
# validation 결과를 저장해서 그려봅시다.
predictions = []
with torch.no_grad():
    for i, (inputs, labels) in enumerate(val_dataloader):
        forecast = model(inputs)
        predictions.append(forecast.data.cpu())
predictions = torch.cat(predictions, dim=0)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-77-5570a878e8ec> in <module>()
#       3 with torch.no_grad():
#       4     for i, (inputs, labels) in enumerate(val_dataloader):
# ----> 5         forecast = model(inputs)
#       6         predictions.append(forecast.data.cpu())
#       7 predictions = torch.cat(predictions, dim=0)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-52-18e0f4eb0fef> in forward(self, backcast)
#      38
#      39         for layer in self.trend_stack:
# ---> 40             b, f = layer(backcast)
#      41             backcast_stack.append(b)
#      42             forecast_stack.append(f)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-52-18e0f4eb0fef> in forward(self, x)
#     100
#     101         # x -> h
# --> 102         x = self.MLP(x.reshape(x.shape[0], -1)) # (batch, backcast length * feature_dim) -> (batch, theta_dim)
#     103 # We can simply call pairplot on our DataFrame for an automatic visual analysis
#     104
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1846     if has_torch_function_variadic(input, weight, bias):
#    1847         return handle_torch_function(linear, (input, weight, bias), input, weight, bias=bias)
# -> 1848     return torch._C._nn.linear(input, weight, bias)
#    1849
#    1850
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu! (when checking argument for argument mat1 in method wrapper_addmm)

# %%
predictions.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-293cacf484d2> in <module>()
# ----> 1 predictions.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
def plot_prediction_after_N_days(real,pred,N=5):
    #
    pred = pred[:,N,:]
    real = real.iloc[N:]
    real = real.iloc[:len(pred)]
    
    cmap=['red','orange','skyblue','green']
    plt.figure(figsize=(16,5))
    for i, col in enumerate(real.columns):
        plt.plot(real[col], label=col+' Real', c=cmap[i], linestyle='--')
    
    pred_df = pd.DataFrame(pred.data.cpu().numpy())
    pred_df.index = real.index
    pred_df.columns = real.columns
    for i, col in enumerate(real.columns):
        plt.plot(pred_df[col], label=col+' Pred', c=cmap[i])
    plt.legend()
    plt.show()

# %%
validation_real = val_df.iloc[backcast_length:]  # 입력으로만 사용된 데이터는 제외하였습니다.
plot_prediction_after_N_days(validation_real, train_dataset.scaler.unscale(predictions), N=1) # N=5 이면 5일 뒤를 예측한 결과를 plot합니다.

# %% [markdown]
# # Test 데이터에도 적용해봅시다.

# %%
predictions = []
with torch.no_grad():
    for i, (inputs, labels) in enumerate(test_dataloader):
        forecast = model(inputs)
        predictions.append(forecast.data.cpu())
predictions = torch.cat(predictions, dim=0)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-79-36c59bd7ef3f> in <module>()
#       2 with torch.no_grad():
#       3     for i, (inputs, labels) in enumerate(test_dataloader):
# ----> 4         forecast = model(inputs)
#       5         predictions.append(forecast.data.cpu())
#       6 predictions = torch.cat(predictions, dim=0)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-52-18e0f4eb0fef> in forward(self, backcast)
#      38
#      39         for layer in self.trend_stack:
# ---> 40             b, f = layer(backcast)
#      41             backcast_stack.append(b)
#      42             forecast_stack.append(f)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-52-18e0f4eb0fef> in forward(self, x)
#     100
#     101         # x -> h
# --> 102         x = self.MLP(x.reshape(x.shape[0], -1)) # (batch, backcast length * feature_dim) -> (batch, theta_dim)
#     103 # We can simply call pairplot on our DataFrame for an automatic visual analysis
#     104
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1846     if has_torch_function_variadic(input, weight, bias):
#    1847         return handle_torch_function(linear, (input, weight, bias), input, weight, bias=bias)
# -> 1848     return torch._C._nn.linear(input, weight, bias)
#    1849
#    1850
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu! (when checking argument for argument mat1 in method wrapper_addmm)

# %%
test_real = test_df.iloc[backcast_length:]  # 입력으로만 사용된 데이터는 제외하였습니다.
plot_prediction_after_N_days(test_real, train_dataset.scaler.unscale(predictions), N=3)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-80-c0c0de3cb915> in <module>()
#       1 test_real = test_df.iloc[backcast_length:]  # 입력으로만 사용된 데이터는 제외하였습니다.
# ----> 2 plot_prediction_after_N_days(test_real, train_dataset.scaler.unscale(predictions), N=3)
#
# <ipython-input-30-aa8819c63419> in unscale(self, x)
#      25         if not torch.is_tensor(x): # numpy array -> torch tensor
#      26             x = torch.tensor(x)
# ---> 27         return x * self.stdev.to(x.device) + self.mean.to(x.device) # 역 연산으로 원래 scale로 돌아가게 한다.
#      28 # We can simply call pairplot on our DataFrame for an automatic visual analysis
#      29
#
# RuntimeError: The size of tensor a (0) must match the size of tensor b (4) at non-singleton dimension 0

# %% [markdown]
# # 6. N-BEATS 모델을 사용해봅시다.

# %%
class NBeatsNet(nn.Module):
    def __init__(self,
                 forecast_length=24,
                 backcast_length=96,
                 theta_dim=(2, 8, 3), # 2차식으로 표현하겠다. trend, seasonal ,residual 
                 n_trend=3,  # stack 하나에 trend block이 몇개 들어있는지
                 n_seasonality=3,
                 n_residual=3,
                 hidden_dim=512,
                 feature_dim=4):
        super(NBeatsNet, self).__init__()        
            
        self.trend_stack = []
        self.seasonality_stack = []
        self.residual_stack = [] #bs =[] 이건했는데 fs=[] 이거 안해줌
        # We can simply call pairplot on our DataFrame for an automatic visual analysis 

        for i in range(n_trend):
            self.trend_stack.append(Block(backcast_length, forecast_length, hidden_dim, theta_dim[0], mode='trend', feature_dim=feature_dim))    

        for i in range(n_seasonality):
            self.seasonality_stack.append(Block(backcast_length, forecast_length, hidden_dim, theta_dim[1], mode='seasonality', feature_dim=feature_dim))
        
        for i in range(n_residual):
            self.residual_stack.append(Block(backcast_length, forecast_length, hidden_dim, theta_dim[2], mode='residual', feature_dim=feature_dim))
        # We can simply call pairplot on our DataFrame for an automatic visual analysis 

        
        self.trend_stack = nn.ModuleList(self.trend_stack)
        self.seasonality_stack = nn.ModuleList(self.seasonality_stack)
        self.residual_stack = nn.ModuleList(self.residual_stack)

    def forward(self, backcast):# We can simply call pairplot on our DataFrame for an automatic visual analysis 
# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        backcast_stack = []
        forecast_stack = []

        for layer in self.trend_stack:
            b, f = layer(backcast)
            backcast_stack.append(b)
            forecast_stack.append(f)
            backcast = backcast - b  # 현재 예측한 backcast만큼 빼줘야지

        for layer in self.seasonality_stack:
            b, f = layer(backcast)
            backcast_stack.append(b)
            forecast_stack.append(f)
            backcast = backcast - b


        for layer in self.residual_stack:
            b, f = layer(backcast)
            backcast_stack.append(b)
            forecast_stack.append(f)
            backcast = backcast - b

        backcast = torch.stack(backcast_stack, 0)  #[trend_b1, trend_b2,trend_b3, sea_b1, sea_b2,,,,,res_b3] block들이 들어가있음
        forecast = torch.stack(forecast_stack, 0)
        return backcast, forecast


# ours
class Block(nn.Module): # Block input 만들기
    def __init__(self, backcast_length, forecast_length, hidden_dim, theta_dim, mode, feature_dim):
        super(Block, self).__init__()
        self.backcast_length = backcast_length
        self.forecast_length = forecast_length
        self.theta_dim = theta_dim
        self.mode = mode

        self.MLP = nn.Sequential(
                nn.Linear(backcast_length * feature_dim, hidden_dim), 
                nn.ReLU(),
                nn.Linear(hidden_dim, hidden_dim),
                nn.ReLU(),
                nn.Linear(hidden_dim, hidden_dim),
                nn.ReLU(),
                nn.Linear(hidden_dim, hidden_dim),
                nn.ReLU() # fully connected stack의 부분.
            ) # univariate??multivariate??

        if mode == 'residual':
            # residual  
            self.theta_b = nn.Linear(hidden_dim, theta_dim * feature_dim) # hidden: 입력 dimension, 뒷부분은 입,출력이 같아야한다. theta_dim만큼 출력한다.       
            self.theta_f = nn.Linear(hidden_dim, theta_dim * feature_dim) 
            self.linear_b = nn.Linear(theta_dim, backcast_length)
            self.linear_f = nn.Linear(theta_dim, forecast_length)
        else:
            # trend, seasonality# We can simply call pairplot on our DataFrame for an automatic visual analysis 

            self.theta = nn.Linear(hidden_dim, theta_dim*feature_dim)


    def forward(self, x):
        shape = x.shape
        # x: (batch size, backcast length, feature_dim)
        t_b = ((torch.arange(start=0, end=self.backcast_length, device=x.device, dtype=torch.float) - self.backcast_length) / 24 ) # (backcast_len,)
        t_f = ((torch.arange(start=0, end=self.forecast_length, device=x.device, dtype=torch.float)) / 24 ) # (forecast_len,)

        # x -> h
        x = self.MLP(x.reshape(x.shape[0], -1)) # (batch, backcast length * feature_dim) -> (batch, theta_dim)
# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        # h -> theta -> backcast, forecast
        if self.mode == 'residual':# We can simply call pairplot on our DataFrame for an automatic visual analysis 

            # residual block
            theta_b = self.theta_b(x).reshape(shape[0], shape[2], self.theta_dim)
            theta_f = self.theta_f(x).reshape(shape[0], shape[2], self.theta_dim)
            b = self.linear_b(theta_b).permute(0,2,1) # (batch, backcast length, feature_dim)  # 재배치 해주는 함수 
            f = self.linear_f(theta_f).permute(0,2,1) # (batch, forecast length, feature_dim)
        else:
            theta_b = self.theta(x).reshape(shape[0], self.theta_dim, shape[2])
            theta_f = theta_b  #같은 예측값을 사용하기로 했기 때문에. 

            # trend와 seasonality 나눠주기
            if self.mode == 'trend':  
                b = self.get_trend(theta_b, t_b) #theta_b와 theta_f를 같게 가져왔기 때문에 t_b, t_f에 따라서 forecast인지 backcast인지 구분한다. 
                f = self.get_trend(theta_f, t_f)
                
            elif self.mode == 'seasonality':
                b = self.get_seasonality(theta_b, t_b)
                f = self.get_seasonality(theta_f, t_f)
        return b, f# We can simply call pairplot on our DataFrame for an automatic visual analysis 


    def get_trend(self, theta, t):
        # theta dim = 0 -> 수평선 (y=a)
        # theta dim = 1 -> 직선 (y=bx)
        # theta dim = 2 -> 이차곡선 (y=cx^2)
        # ...

        T = torch.stack([t ** i for i in range(theta.shape[1])])  # (theta_dim ,sequence length)
        out = torch.einsum('btf,ts->bsf', theta, T) # theta, T를 입력받음

        return out


    def get_seasonality(self, theta, t):
        s1 = torch.stack([torch.cos(2 * np.pi * (i+1) * t) for i in range(self.theta_dim//2)]).float()  # H/2-1
        s2 = torch.stack([torch.sin(2 * np.pi * (i+1) * t) for i in range(self.theta_dim//2)]).float()
        S = torch.cat([s1, s2])# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        out = torch.einsum('btf,ts->bsf', theta, S) 
        return out

# %%
# model hyper parameters
theta_dim=(2, 8, 3) # theta_dim=2 이면 2차곡선, sin_term 4개, cos_term 4개가 반복된다. 
n_trend=3
n_seasonality=3
n_residual=3
hidden_dim=64


model = NBeatsNet(forecast_length, backcast_length, theta_dim, n_trend, n_seasonality, n_residual, hidden_dim)
model = model.cuda()

# We can simply call pairplot on our DataFrame for an automatic visual analysis

# %%
learning_rate = 1e-4

criterion = nn.MSELoss() #nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
num_epoch = 100



import time
train_losses = []
val_losses = []
best_epoch = 0
start_time = time.time()
best_model_state_dict = None
best_val_loss = 10000
for epoch in range(num_epoch):
    train_loss_mean = 0
    val_loss_mean = 0
    
    # train
    model.train()
    for i, (inputs, labels) in enumerate(train_dataloader):
        inputs = inputs.cuda()
        labels = labels.cuda()
        
        forecast = model(inputs)
    
        backcast, forecast = model(inputs)
        loss = criterion(backcast.sum(0), inputs) + criterion(forecast.sum(0), labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_loss_mean += loss.item()
        
        if i % 100 == 0:# We can simply call pairplot on our DataFrame for an automatic visual analysis 

            print('epoch [{}/{}] iter [{:03d}/{:03d}] loss [{:.4f}] elapsed time [{:.2f}min]'.format(epoch, num_epoch, i, len(train_dataloader), loss.item(), (time.time()-start_time)/60))
    
    train_loss_mean = train_loss_mean/len(train_dataloader)
    
    train_losses.append(train_loss_mean)
    
    # validation
    model.eval()
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(val_dataloader):
            inputs = inputs.cuda()
            labels = labels.cuda()

            backcast, forecast = model(inputs)
            loss = criterion(backcast.sum(0), inputs) + criterion(forecast.sum(0), labels)
            val_loss_mean += loss.item()

        val_loss_mean = val_loss_mean/len(val_dataloader)

        print('epoch [{}/{}] train loss [{:.4f}] validation loss [{:.4f}] elapsed time [{:.2f} min]\n'.format(epoch, num_epoch, train_loss_mean, val_loss_mean, (time.time()-start_time)/60))

        if val_loss_mean < best_val_loss:
            best_epoch = epoch
            best_val_loss = val_loss_mean
            best_model_state_dict = model.state_dict()
    val_losses.append(val_loss_mean)
# Out:
# epoch [0/100] iter [000/016] loss [2.7344] elapsed time [0.00min]
# epoch [0/100] train loss [2.6278] validation loss [29.7822] elapsed time [0.02 min]
#
# epoch [1/100] iter [000/016] loss [2.4479] elapsed time [0.03min]
# epoch [1/100] train loss [2.3265] validation loss [26.6746] elapsed time [0.04 min]
#
# epoch [2/100] iter [000/016] loss [2.3607] elapsed time [0.05min]
# epoch [2/100] train loss [2.0041] validation loss [22.2964] elapsed time [0.07 min]
#
# epoch [3/100] iter [000/016] loss [1.7750] elapsed time [0.07min]
# epoch [3/100] train loss [1.6389] validation loss [16.5554] elapsed time [0.09 min]
#
# epoch [4/100] iter [000/016] loss [1.4151] elapsed time [0.09min]
# epoch [4/100] train loss [1.2263] validation loss [10.6042] elapsed time [0.11 min]
#
# epoch [5/100] iter [000/016] loss [1.0770] elapsed time [0.11min]
# epoch [5/100] train loss [0.8863] validation loss [5.9555] elapsed time [0.13 min]
#
# epoch [6/100] iter [000/016] loss [0.7422] elapsed time [0.13min]
# epoch [6/100] train loss [0.6596] validation loss [4.0398] elapsed time [0.15 min]
#
# epoch [7/100] iter [000/016] loss [0.5762] elapsed time [0.15min]
# epoch [7/100] train loss [0.5465] validation loss [3.5380] elapsed time [0.17 min]
#
# epoch [8/100] iter [000/016] loss [0.5035] elapsed time [0.17min]
# epoch [8/100] train loss [0.4802] validation loss [3.1928] elapsed time [0.19 min]
#
# epoch [9/100] iter [000/016] loss [0.4466] elapsed time [0.20min]
# epoch [9/100] train loss [0.4325] validation loss [3.1292] elapsed time [0.21 min]
#
# epoch [10/100] iter [000/016] loss [0.4119] elapsed time [0.22min]
# epoch [10/100] train loss [0.3946] validation loss [3.0238] elapsed time [0.24 min]
#
# epoch [11/100] iter [000/016] loss [0.3827] elapsed time [0.24min]
# epoch [11/100] train loss [0.3603] validation loss [2.9736] elapsed time [0.26 min]
#
# epoch [12/100] iter [000/016] loss [0.3429] elapsed time [0.26min]
# epoch [12/100] train loss [0.3301] validation loss [2.9194] elapsed time [0.28 min]
#
# epoch [13/100] iter [000/016] loss [0.3184] elapsed time [0.28min]
# epoch [13/100] train loss [0.3041] validation loss [2.8565] elapsed time [0.30 min]
#
# epoch [14/100] iter [000/016] loss [0.2841] elapsed time [0.30min]
# epoch [14/100] train loss [0.2818] validation loss [2.7944] elapsed time [0.32 min]
#
# epoch [15/100] iter [000/016] loss [0.2707] elapsed time [0.33min]
# epoch [15/100] train loss [0.2603] validation loss [2.6792] elapsed time [0.34 min]
#
# epoch [16/100] iter [000/016] loss [0.2489] elapsed time [0.35min]
# epoch [16/100] train loss [0.2443] validation loss [2.6514] elapsed time [0.36 min]
#
# epoch [17/100] iter [000/016] loss [0.2345] elapsed time [0.37min]
# epoch [17/100] train loss [0.2277] validation loss [2.6184] elapsed time [0.39 min]
#
# epoch [18/100] iter [000/016] loss [0.2131] elapsed time [0.39min]
# epoch [18/100] train loss [0.2144] validation loss [2.5396] elapsed time [0.41 min]
#
# epoch [19/100] iter [000/016] loss [0.2128] elapsed time [0.41min]
# epoch [19/100] train loss [0.2003] validation loss [2.4287] elapsed time [0.43 min]
#
# epoch [20/100] iter [000/016] loss [0.1957] elapsed time [0.43min]
# epoch [20/100] train loss [0.1893] validation loss [2.4347] elapsed time [0.45 min]
#
# epoch [21/100] iter [000/016] loss [0.1830] elapsed time [0.45min]
# epoch [21/100] train loss [0.1767] validation loss [2.3611] elapsed time [0.47 min]
#
# epoch [22/100] iter [000/016] loss [0.1745] elapsed time [0.48min]
# epoch [22/100] train loss [0.1661] validation loss [2.3034] elapsed time [0.49 min]
#
# epoch [23/100] iter [000/016] loss [0.1549] elapsed time [0.50min]
# epoch [23/100] train loss [0.1560] validation loss [2.2375] elapsed time [0.51 min]
#
# epoch [24/100] iter [000/016] loss [0.1503] elapsed time [0.52min]
# epoch [24/100] train loss [0.1458] validation loss [2.1824] elapsed time [0.53 min]
#
# epoch [25/100] iter [000/016] loss [0.1422] elapsed time [0.54min]
# epoch [25/100] train loss [0.1368] validation loss [2.0986] elapsed time [0.56 min]
#
# epoch [26/100] iter [000/016] loss [0.1303] elapsed time [0.56min]
# epoch [26/100] train loss [0.1279] validation loss [2.0795] elapsed time [0.58 min]
#
# epoch [27/100] iter [000/016] loss [0.1302] elapsed time [0.58min]
# epoch [27/100] train loss [0.1205] validation loss [2.0624] elapsed time [0.60 min]
#
# epoch [28/100] iter [000/016] loss [0.1159] elapsed time [0.60min]
# epoch [28/100] train loss [0.1128] validation loss [1.9626] elapsed time [0.62 min]
#
# epoch [29/100] iter [000/016] loss [0.1067] elapsed time [0.62min]
# epoch [29/100] train loss [0.1058] validation loss [1.9522] elapsed time [0.64 min]
#
# epoch [30/100] iter [000/016] loss [0.1045] elapsed time [0.65min]
# epoch [30/100] train loss [0.0990] validation loss [1.8467] elapsed time [0.66 min]
#
# epoch [31/100] iter [000/016] loss [0.0965] elapsed time [0.67min]
# epoch [31/100] train loss [0.0929] validation loss [1.8423] elapsed time [0.68 min]
#
# epoch [32/100] iter [000/016] loss [0.0884] elapsed time [0.69min]
# epoch [32/100] train loss [0.0872] validation loss [1.7778] elapsed time [0.71 min]
#
# epoch [33/100] iter [000/016] loss [0.0853] elapsed time [0.71min]
# epoch [33/100] train loss [0.0811] validation loss [1.7549] elapsed time [0.73 min]
#
# epoch [34/100] iter [000/016] loss [0.0787] elapsed time [0.73min]
# epoch [34/100] train loss [0.0757] validation loss [1.7266] elapsed time [0.75 min]
#
# epoch [35/100] iter [000/016] loss [0.0758] elapsed time [0.75min]
# epoch [35/100] train loss [0.0717] validation loss [1.6602] elapsed time [0.77 min]
#
# epoch [36/100] iter [000/016] loss [0.0756] elapsed time [0.78min]
# epoch [36/100] train loss [0.0667] validation loss [1.6652] elapsed time [0.79 min]
#
# epoch [37/100] iter [000/016] loss [0.0582] elapsed time [0.80min]
# epoch [37/100] train loss [0.0623] validation loss [1.6196] elapsed time [0.81 min]
#
# epoch [38/100] iter [000/016] loss [0.0587] elapsed time [0.82min]
# epoch [38/100] train loss [0.0584] validation loss [1.6131] elapsed time [0.84 min]
#
# epoch [39/100] iter [000/016] loss [0.0566] elapsed time [0.84min]
# epoch [39/100] train loss [0.0550] validation loss [1.5615] elapsed time [0.86 min]
#
# epoch [40/100] iter [000/016] loss [0.0567] elapsed time [0.86min]
# epoch [40/100] train loss [0.0515] validation loss [1.5430] elapsed time [0.88 min]
#
# epoch [41/100] iter [000/016] loss [0.0497] elapsed time [0.88min]
# epoch [41/100] train loss [0.0481] validation loss [1.4803] elapsed time [0.90 min]
#
# epoch [42/100] iter [000/016] loss [0.0470] elapsed time [0.91min]
# epoch [42/100] train loss [0.0456] validation loss [1.4603] elapsed time [0.92 min]
#
# epoch [43/100] iter [000/016] loss [0.0415] elapsed time [0.93min]
# epoch [43/100] train loss [0.0426] validation loss [1.4395] elapsed time [0.94 min]
#
# epoch [44/100] iter [000/016] loss [0.0412] elapsed time [0.95min]
# epoch [44/100] train loss [0.0402] validation loss [1.4114] elapsed time [0.97 min]
#
# epoch [45/100] iter [000/016] loss [0.0368] elapsed time [0.97min]
# epoch [45/100] train loss [0.0381] validation loss [1.4363] elapsed time [0.99 min]
#
# epoch [46/100] iter [000/016] loss [0.0346] elapsed time [0.99min]
# epoch [46/100] train loss [0.0355] validation loss [1.4410] elapsed time [1.01 min]
#
# epoch [47/100] iter [000/016] loss [0.0350] elapsed time [1.01min]
# epoch [47/100] train loss [0.0333] validation loss [1.3853] elapsed time [1.03 min]
#
# epoch [48/100] iter [000/016] loss [0.0330] elapsed time [1.03min]
# epoch [48/100] train loss [0.0317] validation loss [1.3920] elapsed time [1.05 min]
#
# epoch [49/100] iter [000/016] loss [0.0311] elapsed time [1.05min]
# epoch [49/100] train loss [0.0300] validation loss [1.3308] elapsed time [1.07 min]
#
# epoch [50/100] iter [000/016] loss [0.0288] elapsed time [1.07min]
# epoch [50/100] train loss [0.0286] validation loss [1.3220] elapsed time [1.09 min]
#
# epoch [51/100] iter [000/016] loss [0.0317] elapsed time [1.10min]
# epoch [51/100] train loss [0.0274] validation loss [1.2960] elapsed time [1.11 min]
#
# epoch [52/100] iter [000/016] loss [0.0293] elapsed time [1.12min]
# epoch [52/100] train loss [0.0260] validation loss [1.2849] elapsed time [1.13 min]
#
# epoch [53/100] iter [000/016] loss [0.0263] elapsed time [1.14min]
# epoch [53/100] train loss [0.0250] validation loss [1.2384] elapsed time [1.15 min]
#
# epoch [54/100] iter [000/016] loss [0.0240] elapsed time [1.16min]
# epoch [54/100] train loss [0.0235] validation loss [1.2073] elapsed time [1.18 min]
#
# epoch [55/100] iter [000/016] loss [0.0244] elapsed time [1.18min]
# epoch [55/100] train loss [0.0226] validation loss [1.1958] elapsed time [1.20 min]
#
# epoch [56/100] iter [000/016] loss [0.0221] elapsed time [1.20min]
# epoch [56/100] train loss [0.0219] validation loss [1.1488] elapsed time [1.22 min]
#
# epoch [57/100] iter [000/016] loss [0.0217] elapsed time [1.22min]
# epoch [57/100] train loss [0.0212] validation loss [1.2176] elapsed time [1.24 min]
#
# epoch [58/100] iter [000/016] loss [0.0197] elapsed time [1.24min]
# epoch [58/100] train loss [0.0203] validation loss [1.1707] elapsed time [1.26 min]
#
# epoch [59/100] iter [000/016] loss [0.0197] elapsed time [1.26min]
# epoch [59/100] train loss [0.0197] validation loss [1.1532] elapsed time [1.28 min]
#
# epoch [60/100] iter [000/016] loss [0.0183] elapsed time [1.29min]
# epoch [60/100] train loss [0.0189] validation loss [1.1345] elapsed time [1.30 min]
#
# epoch [61/100] iter [000/016] loss [0.0154] elapsed time [1.31min]
# epoch [61/100] train loss [0.0188] validation loss [1.0981] elapsed time [1.33 min]
#
# epoch [62/100] iter [000/016] loss [0.0201] elapsed time [1.33min]
# epoch [62/100] train loss [0.0181] validation loss [1.0417] elapsed time [1.35 min]
#
# epoch [63/100] iter [000/016] loss [0.0158] elapsed time [1.35min]
# epoch [63/100] train loss [0.0175] validation loss [1.0560] elapsed time [1.37 min]
#
# epoch [64/100] iter [000/016] loss [0.0178] elapsed time [1.37min]
# epoch [64/100] train loss [0.0171] validation loss [1.0479] elapsed time [1.39 min]
#
# epoch [65/100] iter [000/016] loss [0.0180] elapsed time [1.39min]
# epoch [65/100] train loss [0.0166] validation loss [0.9495] elapsed time [1.41 min]
#
# epoch [66/100] iter [000/016] loss [0.0161] elapsed time [1.41min]
# epoch [66/100] train loss [0.0165] validation loss [0.9927] elapsed time [1.43 min]
#
# epoch [67/100] iter [000/016] loss [0.0141] elapsed time [1.44min]
# epoch [67/100] train loss [0.0165] validation loss [0.9747] elapsed time [1.45 min]
#
# epoch [68/100] iter [000/016] loss [0.0177] elapsed time [1.46min]
# epoch [68/100] train loss [0.0161] validation loss [0.9638] elapsed time [1.48 min]
#
# epoch [69/100] iter [000/016] loss [0.0165] elapsed time [1.48min]
# epoch [69/100] train loss [0.0158] validation loss [0.9825] elapsed time [1.50 min]
#
# epoch [70/100] iter [000/016] loss [0.0138] elapsed time [1.50min]
# epoch [70/100] train loss [0.0155] validation loss [1.0246] elapsed time [1.52 min]
#
# epoch [71/100] iter [000/016] loss [0.0150] elapsed time [1.52min]
# epoch [71/100] train loss [0.0152] validation loss [0.9260] elapsed time [1.54 min]
#
# epoch [72/100] iter [000/016] loss [0.0153] elapsed time [1.54min]
# epoch [72/100] train loss [0.0151] validation loss [0.9130] elapsed time [1.56 min]
#
# epoch [73/100] iter [000/016] loss [0.0145] elapsed time [1.56min]
# epoch [73/100] train loss [0.0148] validation loss [0.9355] elapsed time [1.58 min]
#
# epoch [74/100] iter [000/016] loss [0.0161] elapsed time [1.59min]
# epoch [74/100] train loss [0.0145] validation loss [0.9149] elapsed time [1.60 min]
#
# epoch [75/100] iter [000/016] loss [0.0146] elapsed time [1.61min]
# epoch [75/100] train loss [0.0146] validation loss [0.8820] elapsed time [1.62 min]
#
# epoch [76/100] iter [000/016] loss [0.0130] elapsed time [1.63min]
# epoch [76/100] train loss [0.0144] validation loss [0.8738] elapsed time [1.65 min]
#
# epoch [77/100] iter [000/016] loss [0.0149] elapsed time [1.65min]
# epoch [77/100] train loss [0.0143] validation loss [0.8392] elapsed time [1.67 min]
#
# epoch [78/100] iter [000/016] loss [0.0144] elapsed time [1.67min]
# epoch [78/100] train loss [0.0140] validation loss [0.8437] elapsed time [1.69 min]
#
# epoch [79/100] iter [000/016] loss [0.0148] elapsed time [1.69min]
# epoch [79/100] train loss [0.0138] validation loss [0.8952] elapsed time [1.71 min]
#
# epoch [80/100] iter [000/016] loss [0.0145] elapsed time [1.71min]
# epoch [80/100] train loss [0.0137] validation loss [0.8986] elapsed time [1.73 min]
#
# epoch [81/100] iter [000/016] loss [0.0130] elapsed time [1.74min]
# epoch [81/100] train loss [0.0136] validation loss [0.8689] elapsed time [1.75 min]
#
# epoch [82/100] iter [000/016] loss [0.0153] elapsed time [1.76min]
# epoch [82/100] train loss [0.0136] validation loss [0.8799] elapsed time [1.77 min]
#
# epoch [83/100] iter [000/016] loss [0.0135] elapsed time [1.78min]
# epoch [83/100] train loss [0.0134] validation loss [0.8445] elapsed time [1.79 min]
#
# epoch [84/100] iter [000/016] loss [0.0135] elapsed time [1.80min]
# epoch [84/100] train loss [0.0136] validation loss [0.8938] elapsed time [1.82 min]
#
# epoch [85/100] iter [000/016] loss [0.0129] elapsed time [1.82min]
# epoch [85/100] train loss [0.0135] validation loss [0.8687] elapsed time [1.84 min]
#
# epoch [86/100] iter [000/016] loss [0.0120] elapsed time [1.84min]
# epoch [86/100] train loss [0.0133] validation loss [0.8123] elapsed time [1.86 min]
#
# epoch [87/100] iter [000/016] loss [0.0115] elapsed time [1.86min]
# epoch [87/100] train loss [0.0131] validation loss [0.8519] elapsed time [1.88 min]
#
# epoch [88/100] iter [000/016] loss [0.0134] elapsed time [1.88min]
# epoch [88/100] train loss [0.0130] validation loss [0.8916] elapsed time [1.90 min]
#
# epoch [89/100] iter [000/016] loss [0.0139] elapsed time [1.90min]
# epoch [89/100] train loss [0.0130] validation loss [0.8331] elapsed time [1.92 min]
#
# epoch [90/100] iter [000/016] loss [0.0120] elapsed time [1.92min]
# epoch [90/100] train loss [0.0129] validation loss [0.8251] elapsed time [1.94 min]
#
# epoch [91/100] iter [000/016] loss [0.0118] elapsed time [1.95min]
# epoch [91/100] train loss [0.0129] validation loss [0.8577] elapsed time [1.96 min]
#
# epoch [92/100] iter [000/016] loss [0.0135] elapsed time [1.97min]
# epoch [92/100] train loss [0.0127] validation loss [0.8528] elapsed time [1.99 min]
#
# epoch [93/100] iter [000/016] loss [0.0138] elapsed time [1.99min]
# epoch [93/100] train loss [0.0127] validation loss [0.8625] elapsed time [2.01 min]
#
# epoch [94/100] iter [000/016] loss [0.0124] elapsed time [2.01min]
# epoch [94/100] train loss [0.0127] validation loss [0.7564] elapsed time [2.03 min]
#
# epoch [95/100] iter [000/016] loss [0.0123] elapsed time [2.03min]
# epoch [95/100] train loss [0.0125] validation loss [0.8367] elapsed time [2.05 min]
#
# epoch [96/100] iter [000/016] loss [0.0105] elapsed time [2.05min]
# epoch [96/100] train loss [0.0125] validation loss [0.9029] elapsed time [2.07 min]
#
# epoch [97/100] iter [000/016] loss [0.0117] elapsed time [2.08min]
# epoch [97/100] train loss [0.0123] validation loss [0.8403] elapsed time [2.09 min]
#
# epoch [98/100] iter [000/016] loss [0.0135] elapsed time [2.10min]
# epoch [98/100] train loss [0.0121] validation loss [0.7807] elapsed time [2.11 min]
#
# epoch [99/100] iter [000/016] loss [0.0112] elapsed time [2.12min]
# epoch [99/100] train loss [0.0122] validation loss [0.8464] elapsed time [2.14 min]

# %%
 plt.figure(figsize=(10,5))
plt.plot(train_losses, label='train loss')
plt.plot(val_losses, label='validation loss')
plt.axvline(best_epoch, color='red') # early stopping best에서 멈추기 
plt.legend()
plt.show()

# %%
# validation 결과를 저장해서 그려봅시다.
predictions = []
with torch.no_grad():
    for i, (inputs, labels) in enumerate(val_dataloader):
        inputs = inputs.cuda()
        backcast, forecast = model(inputs)
        predictions.append(forecast.sum(0).data.cpu())
predictions = torch.cat(predictions, dim=0)

validation_real = val_df.iloc[backcast_length:]  # 입력으로만 사용된 데이터는 제외하였습니다.
plot_prediction_after_N_days(validation_real, train_dataset.scaler.unscale(predictions), N=1) # N=5 이면 5일 뒤를 예측한 결과를 plot합니다.

# %%
# test 결과를 저장해서 그려봅시다.
predictions = []
with torch.no_grad():
    for i, (inputs, labels) in enumerate(test_dataloader):
        inputs = inputs.cuda()
        backcast, forecast = model(inputs)
        predictions.append(forecast.sum(0).data.cpu())
predictions = torch.cat(predictions, dim=0)

test_real = test_df.iloc[backcast_length:]  # 입력으로만 사용된 데이터는 제외하였습니다.
plot_prediction_after_N_days(test_real, train_dataset.scaler.unscale(predictions), N=3)# We can simply call pairplot on our DataFrame for an automatic visual analysis

# %%
def MAE(x, y):
    return np.mean(np.abs(x-y))
  
def RMSE(x,y):
    return np.sqrt(np.mean((x-y))**2)

def metric(real, pred, N=5):
    pred = pred[:,N,:]
    real = real.iloc[N:]
    real = real.iloc[:len(pred)]

    pred = np.array(pred)
    real = np.array(real)

    mae = MAE(pred, real)
    rmse = RMSE(pred, real)

    return mae, rmse

# %%
mae, rmse = metric(test_real, train_dataset.scaler.unscale(predictions), N=5) # 5일뒤 예측결과

print('MAE: {:.3f}'.format(mae))
print('RMSE: {:.3f}'.format(rmse))
# Out:
# MAE: 160.449
# RMSE: 153.438
